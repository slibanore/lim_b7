# %%
import matplotlib.path as mpath
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from matplotlib.collections import PatchCollection
import matplotlib.pyplot as plt
from LIM_b7 import *

fig, (ax,axg) = plt.subplots(1,2,figsize = (20,10))


survey = [r'$\rm AtLAST$',
          r'$\rm CCAT-prime$']

Ommax = [7500,
        8]

zmin = [1.06,3.43]

zmax = [5.05,8.49
        ]

pos_x = [1500,1]

pos_y = [(zmin[0]+zmax[0])/2.-0.25,(zmin[1]+zmax[1])/2.-1.75]

patches =[]
for i in range(len(survey)):
    fancybox = mpatches.FancyBboxPatch(
        [0.,zmin[i]],Ommax[i], zmax[i]-zmin[i],
        boxstyle=mpatches.BoxStyle("Round", pad=0.02))
    patches.append(fancybox)
    if i == 0:
        ax.vlines(0.,zmin[i],zmax[i],color=seiheki, linestyle=':',label=r'$\rm CII$')
    ax.text(pos_x[i], pos_y[i], survey[i], ha="center", family='sans-serif', size=25,color=seiheki)

collection = PatchCollection(patches, alpha=0.2, color=seiheki)
ax.add_collection(collection)

survey = [ r'$\rm SPHEREx$' ,#+ '\n' + r'$\rm high\, \nu$', 
           #r'$\rm SPHEREx$' + '\n' + r'$\rm low\, \nu$', 
           r'$\rm HETDEX \,high\, \nu$', 
           r'$\rm HETDEX \, low\, \nu$', r'$\rm ULTRASAT$']


Ommax = [200, #200, 
         300, 300,41253]

zmin = [4.68, #6.83,
        1.73, 2.83,0.89]

zmax = [#7.27, 
        12.04,
        2.43, 3.81,1.38]

pos_x = [40,#4,
        40,40,40]

pos_y = [(zmin[0]+zmax[0])/2.-1.45,#(zmin[2]+zmax[2])/2.-1.1,
        (zmin[1]+zmax[1])/2.-0.1,(zmin[2]+zmax[2])/2.-0.15,(zmin[-1]+zmax[-1])/2.-0.13]



patches =[]
for i in range(len(survey)):
    fancybox = mpatches.FancyBboxPatch(
    [0.,zmin[i]], Ommax[i], zmax[i]-zmin[i],
    boxstyle=mpatches.BoxStyle("Round", pad=0.02))
    patches.append(fancybox)
    if r'$\rm HETDEX$' in survey[i]:
        ax.vlines(150,zmin[i],zmax[i],color=kitsune, linestyle=':')
    if r'$\rm SPHEREx$' in survey[i]:
        if i == 0:
            ax.hlines(6.83,0.,Ommax[i],color=kitsune, linestyle=':',label=r'$\rm Ly\alpha$')
        else:
            ax.hlines(6.83,0.,Ommax[i],color=kitsune, linestyle=':')
        ax.hlines(7.27,0.,Ommax[i],color=kitsune, linestyle=':')
    ax.text(pos_x[i], pos_y[i], survey[i], ha="center", family='sans-serif', size=25)


collection = PatchCollection(patches, alpha=0.25, color = kitsune)
ax.add_collection(collection)

survey = [r'$\rm COMAP$-$\rm EoR$' + '\n' +r'$\rm COS3\, high\, \nu$', 
          r'$\rm COMAP$-$\rm EoR$' + '\n' +r'$\rm COS3\, low\, \nu$',]

Ommax = [4, 4,
        ]

zmin = [2.4,
        4.8]

zmax = [3.4,
        7.8]

pos_x = [0.6,0.6]

pos_y = [(zmin[0]+zmax[0])/2.-0.3,
        (zmin[1]+zmax[1])/2.-0.4,]

patches =[]
for i in range(len(survey)):
    fancybox = mpatches.FancyBboxPatch(
        [0.,zmin[i]],Ommax[i], zmax[i]-zmin[i],
        boxstyle=mpatches.BoxStyle("Round", pad=0.02))
    patches.append(fancybox)
    if r'$\rm COMAP$-$\rm EoR$' in survey[i]:
        if i == 0:
            ax.vlines(0.5,zmin[i],zmax[i],color=suoko, linestyle=':',label=r'$\rm CO$')
        else:
            ax.vlines(0.5,zmin[i],zmax[i],color=suoko, linestyle=':')
    ax.text(pos_x[i], pos_y[i], survey[i], ha="center", family='sans-serif', size=25,color=suoko)

collection = PatchCollection(patches, alpha=0.2, color='r')
ax.add_collection(collection)


ax.set_xlabel(r'$\Delta\Omega\,{\rm [deg^2]}$',fontsize=40)
ax.set_ylabel(r'$z$',fontsize=40)

ax.xaxis.set_tick_params(labelsize=40)
ax.yaxis.set_tick_params(labelsize=40)

ax.set_xlim(0.11,41253)
ax.set_ylim(0.1,10)
ax.set_xscale('log')

ax.legend(loc=1,fontsize=30)

axg.set_xlabel(r'$\Delta\Omega\,{\rm [deg^2]}$',fontsize=40)
axg.set_ylabel(r'$z$',fontsize=40)

axg.xaxis.set_tick_params(labelsize=40)
axg.yaxis.set_tick_params(labelsize=40)

axg.set_xlim(0.11,41253)
axg.set_ylim(0.1,10)
axg.set_xscale('log')

survey = [r'$\rm EUCLID$', 
          r'$\rm SPHEREx$',
          r'$\rm VRO$-$\rm LSST$']

Ommax = [1.5e4, 0.75*41253,1.8e3
        ]

zmin = [0,
        0,0]

zmax = [1.7,
        3,1]

pos_x = [10,40,2]

pos_y = [(zmin[0]+zmax[0])/2+.4,
        (zmin[1]+zmax[1])/2+.75,(zmin[2]+zmax[2])/2.-.05,]

patches =[]
for i in range(len(survey)):
    fancybox = mpatches.FancyBboxPatch(
        [0.,zmin[i]],Ommax[i], zmax[i]-zmin[i],
        boxstyle=mpatches.BoxStyle("Round", pad=0.02))
    patches.append(fancybox)
    if i == 0:
        axg.vlines(0.,zmin[i],zmax[i],color='k', linestyle=':',label=r'$\rm Resolved\, galaxies$')
    axg.text(pos_x[i], pos_y[i], survey[i], ha="center", family='sans-serif', size=25,color='k')

collection = PatchCollection(patches, alpha=0.2, color='k')
axg.add_collection(collection)

survey = [r'$\rm HST$']

Ommax = [0.47**2
        ]

zmin = [4,
        ]

zmax = [10,
        ]

pos_x = [.2]

pos_y = [(zmin[0]+zmax[0])/2,
        ]

patches =[]
for i in range(len(survey)):
    fancybox = mpatches.FancyBboxPatch(
        [0.,zmin[i]],Ommax[i], zmax[i]-zmin[i],
        boxstyle=mpatches.BoxStyle("Round", pad=0.02))
    patches.append(fancybox)
    if i == 0:
        axg.vlines(0.,zmin[i],zmax[i],color='navy', linestyle=':',label=r'$\rm UV\, LF$')
    axg.text(pos_x[i], pos_y[i], survey[i], ha="center", family='sans-serif', size=25,color='k')

collection = PatchCollection(patches, alpha=0.2, color='navy')
axg.add_collection(collection)



axg.legend(loc=1, fontsize=30)

fig.tight_layout()
fig.savefig('/home/sarah/Documents/my_work/talk/surveys_forecast.png')

# %%
pl.rcParams['hatch.linewidth'] = 2.0  # previous svg hatch linewidt

fig, (ax,axg) = plt.subplots(1,2,figsize = (20,10))

ax2=ax.twiny()
ax2g=axg.twiny()

survey = [r'$\rm AtLAST$',
          r'$\rm CCAT-prime$']

Ommax = [7500,
        8]

zmin = [1.06,3.43]

zmax = [5.05,8.49
        ]

pos_x = [1500,1]

pos_y = [(zmin[0]+zmax[0])/2.-0.25,(zmin[1]+zmax[1])/2.-1.75]

patches =[]
for i in range(len(survey)):
    fancybox = mpatches.FancyBboxPatch(
        [0.,zmin[i]],Ommax[i], zmax[i]-zmin[i],
        boxstyle=mpatches.BoxStyle("Round", pad=0.02))
    patches.append(fancybox)
    if i == 0:
        ax2.vlines(0.,zmin[i],zmax[i],color=seiheki, linestyle=':',label=r'$\rm CII$')
    ax2.text(pos_x[i], pos_y[i], survey[i], ha="center", family='sans-serif', size=25,color=seiheki)

collection = PatchCollection(patches, alpha=0.2, color=seiheki)
ax2.add_collection(collection)

survey = [ r'$\rm SPHEREx$' ,#+ '\n' + r'$\rm high\, \nu$', 
           #r'$\rm SPHEREx$' + '\n' + r'$\rm low\, \nu$', 
           r'$\rm HETDEX \,high\, \nu$', 
           r'$\rm HETDEX \, low\, \nu$', r'$\rm ULTRASAT$']


Ommax = [200, #200, 
         300, 300,41253]

zmin = [4.68, #6.83,
        1.73, 2.83,0.89]

zmax = [#7.27, 
        12.04,
        2.43, 3.81,1.38]

pos_x = [40,#4,
        40,40,40]

pos_y = [(zmin[0]+zmax[0])/2.-1.45,#(zmin[2]+zmax[2])/2.-1.1,
        (zmin[1]+zmax[1])/2.-0.1,(zmin[2]+zmax[2])/2.-0.15,(zmin[-1]+zmax[-1])/2.-0.13]



patches =[]
for i in range(len(survey)):
    fancybox = mpatches.FancyBboxPatch(
    [0.,zmin[i]], Ommax[i], zmax[i]-zmin[i],
    boxstyle=mpatches.BoxStyle("Round", pad=0.02))
    patches.append(fancybox)
    if r'$\rm HETDEX$' in survey[i]:
        ax2.vlines(150,zmin[i],zmax[i],color=kitsune, linestyle=':')
    if r'$\rm SPHEREx$' in survey[i]:
        if i == 0:
            ax2.hlines(6.83,0.,Ommax[i],color=kitsune, linestyle=':',label=r'$\rm Ly\alpha$')
        else:
            ax2.hlines(6.83,0.,Ommax[i],color=kitsune, linestyle=':')
        ax2.hlines(7.27,0.,Ommax[i],color=kitsune, linestyle=':')
    ax2.text(pos_x[i], pos_y[i], survey[i], ha="center", family='sans-serif', size=25)


collection = PatchCollection(patches, alpha=0.25, color = kitsune)
ax2.add_collection(collection)

survey = [r'$\rm COMAP$-$\rm EoR$' + '\n' +r'$\rm COS3\, high\, \nu$', 
          r'$\rm COMAP$-$\rm EoR$' + '\n' +r'$\rm COS3\, low\, \nu$',]

Ommax = [4, 4,
        ]

zmin = [2.4,
        4.8]

zmax = [3.4,
        7.8]

pos_x = [0.6,0.6]

pos_y = [(zmin[0]+zmax[0])/2.-0.3,
        (zmin[1]+zmax[1])/2.-0.4,]

patches =[]
for i in range(len(survey)):
    fancybox = mpatches.FancyBboxPatch(
        [0.,zmin[i]],Ommax[i], zmax[i]-zmin[i],
        boxstyle=mpatches.BoxStyle("Round", pad=0.02))
    patches.append(fancybox)
    if r'$\rm COMAP$-$\rm EoR$' in survey[i]:
        if i == 0:
            ax2.vlines(0.5,zmin[i],zmax[i],color=suoko, linestyle=':',label=r'$\rm CO$')
        else:
            ax2.vlines(0.5,zmin[i],zmax[i],color=suoko, linestyle=':')
    ax2.text(pos_x[i], pos_y[i], survey[i], ha="center", family='sans-serif', size=25,color=suoko)

collection = PatchCollection(patches, alpha=0.2, color='r')
ax2.add_collection(collection)


ax.set_xlabel(r'$k\,{\rm [Mpc^{-1}]}$',fontsize=40)
ax.set_ylabel(r'$z$',fontsize=40)

ax.xaxis.set_tick_params(labelsize=40)
ax.yaxis.set_tick_params(labelsize=40)

ax.set_ylim(0.1,10)
ax2.set_ylim(0.1,10)
ax.set_xscale('log')
ax2.set_xscale('log')
ax2g.set_xscale('log')

ax2.legend(loc=1,fontsize=30)

axg.set_xlabel(r'$k\,{\rm [Mpc^{-1}]}$',fontsize=40)
axg.set_ylabel(r'$z$',fontsize=40)

axg.xaxis.set_tick_params(labelsize=40)
axg.yaxis.set_tick_params(labelsize=40)

axg.set_xlim(100,1e-2)
axg.set_ylim(0.1,10)
ax2g.set_ylim(0.1,10)
axg.set_xscale('log')

survey = [r'$\rm EUCLID$', 
          r'$\rm SPHEREx$',
          r'$\rm VRO$-$\rm LSST$']

Ommax = [1.5e4, 0.75*41253,1.8e3
        ]

zmin = [0,
        0,0]

zmax = [1.7,
        3,1]

pos_x = [10,40,2]

pos_y = [(zmin[0]+zmax[0])/2+.4,
        (zmin[1]+zmax[1])/2+.75,(zmin[2]+zmax[2])/2.-.05,]

patches =[]
for i in range(len(survey)):
    fancybox = mpatches.FancyBboxPatch(
        [0.,zmin[i]],Ommax[i], zmax[i]-zmin[i],
        boxstyle=mpatches.BoxStyle("Round", pad=0.02))
    patches.append(fancybox)
    if i == 0:
        ax2g.vlines(0.,zmin[i],zmax[i],color='k', linestyle=':',label=r'$\rm Resolved\, galaxies$')
    ax2g.text(pos_x[i], pos_y[i], survey[i], ha="center", family='sans-serif', size=25,color='k')

collection = PatchCollection(patches, alpha=0.2, color='k')
ax2g.add_collection(collection)

survey = [r'$\rm HST$']

Ommax = [0.48**2
        ]

zmin = [4,
        ]

zmax = [10,
        ]

pos_x = [.2]

pos_y = [(zmin[0]+zmax[0])/2,
        ]

patches =[]
for i in range(len(survey)):
    fancybox = mpatches.FancyBboxPatch(
        [0.,zmin[i]],Ommax[i], zmax[i]-zmin[i],
        boxstyle=mpatches.BoxStyle("Round", pad=0.02))
    patches.append(fancybox)
    if i == 0:
        ax2g.vlines(0.,zmin[i],zmax[i],color='navy', linestyle=':',label=r'$\rm UV\, LF$')
    ax2g.text(pos_x[i], pos_y[i], survey[i], ha="center", family='sans-serif', size=25,color='k')

collection = PatchCollection(patches, alpha=0.2, color='navy')
ax2g.add_collection(collection)



#ax2.tick_params(axis='x', which='major', pad = 1)
#ax.set_xlabel(r'$\Delta\Omega [{\rm deg}^2]$', labelpad=7, fontsize = 40)
ax2.xaxis.set_ticks([])
ax2.set_xlim(0.11,41253)


#ax2g.tick_params(axis='x', which='major', pad = 1)
#axg.set_xlabel(r'$\Delta\Omega [{\rm deg}^2]$', labelpad=7, fontsize = 40)
ax2g.xaxis.set_ticks([])
ax2g.set_xlim(0.11,41253)

temp = np.genfromtxt('z_knl.txt')
z = temp[:,0]
k = temp[:,1]

ax.plot(k,z,'k-')
ax.fill_between(k,0,z,edgecolor='k',hatch='//',linewidth=1.5,facecolor='white')
axg.fill_between(k,0,z,edgecolor='k',hatch='//',facecolor='white',linewidth=1.5)

axg.plot(k,z,'k-')
ax.set_xscale('log')
axg.set_xscale('log')

ax.set_xlim(100,1.1e-2)
axg.set_xlim(100,1.1e-2)

ax2g.legend(loc=1, fontsize=30)

fig.tight_layout()
fig.savefig('/home/sarah/Documents/my_work/talk/z_klin.png')
